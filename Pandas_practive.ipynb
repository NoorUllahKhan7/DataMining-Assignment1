# %%
#importing pandas
import pandas as pd

# %%
#creating a series type
car_names = pd.Series(["Honda","BMW","Ferarri"])
car_names
# Out:
# 0      Honda
# 1        BMW
# 2    Ferarri
# dtype: object

# %%
#creating 2nd series type
car_color = pd.Series(["Blue","White","Green"])
car_color
# Out:
# 0     Blue
# 1    White
# 2    Green
# dtype: object

# %%
#Creating Data Frame
car_details = pd.DataFrame({"Car_type":car_names, "Car_color":car_color})
car_details
# Out:
#   Car_type Car_color
# 0    Honda      Blue
# 1      BMW     White
# 2  Ferarri     Green

# %%
#importing csv file
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting csv file
car_sales.to_csv("Changed_car_data.csv", index=False)

# %%
#Again importing csv file just exported
changed_car_data = pd.read_csv("Changed_car_data.csv")
changed_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
#finding data types or our frame
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#finding index of a frame
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#describing our data frame
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
#Getting information about whole frame
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
#Finding mean of doors column
car_sales["Doors"].mean()
# Out:
# 4.0

# %%
#Finding sum of doors column
car_sales["Doors"].sum()
# Out:
# 40

# %%
#Finding no of columns in our data frame
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and Selecting data

# %%
#Printing first 5 rows of a data frame
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
#Printing first 7 rows of a data frame
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
#printing make column
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %% [markdown]
# ## Using loc and iloc funtion to index data frames

# %%
#using loc
animals = pd.Series(["parrot","cat","dog"], index = [4,4,3])
animals
# Out:
# 4    parrot
# 4       cat
# 3       dog
# dtype: object

# %%
#printing using loc
animals.loc[4]
# Out:
# 4    parrot
# 4       cat
# dtype: object

# %%
#printing using iloc
car_sales.iloc[1]
# Out:
# Make                 Honda
# Colour                 Red
# Odometer (KM)        87899
# Doors                    4
# Price            $5,000.00
# Name: 1, dtype: object

# %%
#slicing using iloc
car_sales.iloc[0:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
#conditional slicing using iloc
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 1000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"] , car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#group by function
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Make"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-e8f8b05fdd5b> in <module>
# ----> 1 car_sales["Make"].plot()
#
# H:\Latest data science courses\My first project\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# H:\Latest data science courses\My first project\env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["price"].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# H:\Latest data science courses\My first project\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-c0c608fb6212> in <module>
# ...

# %%
car_sales['Price'] = car_sales['Price'].replace('[\$\,]', '', regex=True).astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %% [markdown]
# ## Manipulating data

# %%
#making first column lower case 
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
#Importing csv with missing values
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")

# %%
car_sales_missing.head(20)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 7    Honda  White            NaN    4.0  20306.0
# 8      NaN  White       130538.0    4.0   9374.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13     NaN  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# ...

# %%
#using inplace to update column permanently
#car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean(), inplace = True)

# %%
#without using inplace
car_sales_missing_dropped = car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"])

# %%
#dropping rows having na values using dropna function
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [815 rows x 5 columns]

# %%
car_sales_missing_dropped.to_csv("car_slaes_missing_dropped.csv")

# %%
#Taking a sample basically it randomize data 
car_sales = car_sales.sample(frac = 1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 1   honda    Red          87899      4   5000.0
# 5  toyota  Green          99213      4   4500.0
# 2  toyota   Blue          32549      3   7000.0
# 6   honda   Blue          45698      4   7500.0
# 4  nissan  White         213095      4   3500.0
# 9  nissan  White          31600      4   9700.0
# 8  toyota  White          60000      4   6250.0
# 7   honda   Blue          54738      4   7000.0
# 0  toyota  White         150043      4   4000.0
# 3     bmw  Black          11179      5  22000.0

# %%
# Now we will reset the randomized data and dropping index using drop which were added while taking sample
car_sales.reset_index(inplace = True, drop= True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   honda    Red          87899      4   5000.0
# 1  toyota  Green          99213      4   4500.0
# 2  toyota   Blue          32549      3   7000.0
# 3   honda   Blue          45698      4   7500.0
# 4  nissan  White         213095      4   3500.0
# 5  nissan  White          31600      4   9700.0
# 6  toyota  White          60000      4   6250.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White         150043      4   4000.0
# 9     bmw  Black          11179      5  22000.0
